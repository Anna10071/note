# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.globals import ThemeType

# %%
bar=Bar()
bar.add_xaxis(["衬衫","羊毛衫","雪纺衫","裤子","高跟鞋","袜子"])
bar.add_yaxis("商家A",[5,20,36,10,75,90])
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="77f55206d12d458d9a6b547c189000fe" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_77f55206d12d458d9a6b547c189000fe = echarts.init(
#                     document.getElementById('77f55206d12d458d9a6b547c189000fe'), 'white', {renderer: 'canvas'});
#                 var option_77f55206d12d458d9a6b547c189000fe = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # 链式调用：

# %%
#不换行，一排写
Bar().add_xaxis(["衬衫","羊毛衫","雪纺衫","裤子","高跟鞋","袜子"]).add_yaxis("商家A",[5,20,36,10,75,90]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d6a5bbfd0a93467f88dc55f6eb3039f6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d6a5bbfd0a93467f88dc55f6eb3039f6 = echarts.init(
#                     document.getElementById('d6a5bbfd0a93467f88dc55f6eb3039f6'), 'white', {renderer: 'canvas'});
#                 var option_d6a5bbfd0a93467f88dc55f6eb3039f6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#换行写，需要加上圆括号
(
Bar()
    .add_xaxis(["衬衫","羊毛衫","雪纺衫","裤子","高跟鞋","袜子"])
    .add_yaxis("商家A",[5,20,36,10,75,90])
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="71b8aa3026744a3bb697bc1dd398f08b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_71b8aa3026744a3bb697bc1dd398f08b = echarts.init(
#                     document.getElementById('71b8aa3026744a3bb697bc1dd398f08b'), 'white', {renderer: 'canvas'});
#                 var option_71b8aa3026744a3bb697bc1dd398f08b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # InitOpts:初始化配置项

# %%
c=(
    Bar(init_opts=opts.InitOpts(
            width="500px",#设置宽度
            height="400px",#设置高度
            bg_color="#ccc",#设置背景颜色
            animation_opts=opts.AnimationOpts(animation=False)#设置动画，这里是关掉了动画
          
    ))
    .add_xaxis(Faker.choose())#在Faker中随机选取
    .add_yaxis("商家A",Faker.values())
    .add_yaxis("商家B",Faker.values())
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e13a6a179a7c498f8c531043003bff38" style="width:500px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e13a6a179a7c498f8c531043003bff38 = echarts.init(
#                     document.getElementById('e13a6a179a7c498f8c531043003bff38'), 'white', {renderer: 'canvas'});
#                 var option_e13a6a179a7c498f8c531043003bff38 = {
#     "backgroundColor": "#ccc",
#     "animation": false,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %% [markdown]
# # 标题配置项

# %%
c=(
    Bar(
           )
    .add_xaxis(Faker.choose())#在Faker中随机选取
    .add_yaxis("商家A",Faker.values())
    .add_yaxis("商家B",Faker.values())
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d49f557ce92b4a33815168abc59d8700" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d49f557ce92b4a33815168abc59d8700 = echarts.init(
#                     document.getElementById('d49f557ce92b4a33815168abc59d8700'), 'white', {renderer: 'canvas'});
#                 var option_d49f557ce92b4a33815168abc59d8700 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
c=(
    Bar()
)
